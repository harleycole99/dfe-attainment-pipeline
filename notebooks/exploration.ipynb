# %%
import pandas as pd

# %%
chars = pd.read_csv('../data/aggregated_attainment_by_characteristic_202125.csv')
region = pd.read_csv('../data/aggregated_attainment_by_region_characteristic_202125.csv')
timeseries = pd.read_csv('../data/aggregated_attainment_timeseries_201625.csv')
# Out:
# /var/folders/9m/nb6yjq5x3x99h8jlyqt_vjrh0000gn/T/ipykernel_63686/3824491356.py:2: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   region = pd.read_csv('../data/aggregated_attainment_by_region_characteristic_202125.csv')

# %%
timeseries.head()
# Out:
#    time_period time_identifier geographic_level country_code country_name  \
# 0       201516   Academic year         National    E92000001      England
# 1       201516   Academic year         National    E92000001      England
# 2       201516   Academic year         National    E92000001      England
# 3       201516   Academic year         National    E92000001      England
# 4       201516   Academic year         National    E92000001      England
#
#    version characteristic_type          characteristic_value  \
# 0  Revised        Disadvantage                 Disadvantaged
# 1  Revised        Disadvantage             Non-Disadvantaged
# 2  Revised        Disadvantage  Unknown disadvantaged status
# 3  Revised        All Students     All state-funded students
# 4  Revised        All Students                  All students
#
#   number_of_students_potential number_of_students_level3  ...  \
# 0                            x                         x  ...
# ...
